# %% [markdown]
# # CBA 2020
# ## Detecção de anomalias em poços produtores de petróleo usando aprendizado de máquina

# %% [markdown]
# **_Principais Referências_**
#
# - **A Realistic and Public Dataset with Rare Undesirable Real Events in Oil Wells** ([link](https://doi.org/10.1016/j.petrol.2019.106223)).
# - **Github de referência do _benchmark_ proposto por Vargas (2019)** ([link](https://github.com/ricardovvargas/3w_dataset)).

# %% [markdown]
# ## 1. Regras do benchmark proposto por Vargas (2019)

# %% [markdown]
# - Apenas instâncias reais com anomalias de tipos que têm períodos normais maiores ou iguais a vinte minutos foram utilizadas;
#
# - Múltiplas rodadas de treinamento e validação realizadas, sendo o número de rodadas igual ao número de instâncias. Em cada rodada, amostras utilizadas para treinamento ou validação extraídas de apenas uma instância. Parte das amostras de normalidade utilizadas no treinamento (60%) e a outra parte para teste (40%). As amostras de anomalias somente devem ser utilizadas apenas teste, sendo, portanto, uma técnica de treinamento de classe única. O conjunto de teste deve ser composto pelo mesmo número de amostras de cada classe (normalidade e anormalidade);
#
# - Em cada rodada, precisão, revogação e medida F1 devem ser computadas (valor médio e desvio padrão de cada métrica), sendo o valor médio da medida F1 considerado a principal métrica de desempenho.

# %% [markdown]
# ## 1.1 Outras definições adotadas

# %% [markdown]
# - Uma estratégia de amostragem específica com janela deslizante foi usada para cada tipo de período. Em períodos normais, as primeiras observações são usadas para treinamento e as últimas são usadas para testes. Em períodos transientes, procura-se usar observações como um todo (apenas para teste). Em períodos de regime, as primeiras observações são privilegiadas (somente para teste);
#
# - Antes de cada rodada de treinamento e teste:
#     - As amostras utilizadas (não as instâncias) são adequadamente normalizadas com o z-score;
#     - As variáveis de amostras (não as instâncias) usadas para treinamento que possuem um número de NaNs acima de um limite ou que têm um desvio padrão abaixo de um outro limite são descartadas.
#
# - Todos os random_state necessários são atribuídos a uma constante para que os resultados sejam reproduzíveis.

# %% [markdown]
# ## 2. Bibliotecas e configurações

# %%
# Artifício para alcular tempo total do notebook Jupyter
from datetime import datetime 
start_time = datetime.now()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import logging
import warnings
import sys
sys.path.append('stac')
import nonparametric_tests as stac
from math import ceil
from matplotlib import pyplot as plt
from time import time
from pathlib import Path
from tsfresh.feature_extraction import extract_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import MinimalFCParameters, EfficientFCParameters
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.dummy import DummyClassifier
from sklearn.covariance import EllipticEnvelope
from sklearn.neighbors import LocalOutlierFactor
from sklearn.model_selection import ParameterGrid
from sklearn import preprocessing
from sklearn.metrics import precision_recall_fscore_support

# %%
logging.getLogger('tsfresh').setLevel(logging.ERROR)
warnings.simplefilter(action='ignore')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
data_path = Path('./', 'data')
random_state = 1
events_names = {0: 'Normal',
                1: 'Aumento Abrupto de BSW',
                2: 'Fechamento Espúrio de DHSV',
                3: 'Intermitência Severa',
                4: 'Instabilidade de Fluxo',
                5: 'Perda Rápida de Produtividade',
                6: 'Restrição Rápida em CKP',
                7: 'Incrustação em CKP',
                8: 'Hidrato em Linha de Produção'
               }
vars = ['P-PDG',
        'P-TPT',
        'T-TPT',
        'P-MON-CKP',
        'T-JUS-CKP',
        'P-JUS-CKGL',
        'T-JUS-CKGL',
        'QGL']
columns = ['timestamp'] + vars + ['class'] 
normal_class_code = 0
abnormal_classes_codes = [1, 2, 5, 6, 7, 8]
sample_size = 3*60              # Nas observações = segundos
min_normal_period_size = 20*60  # Nas observações = segundos
split_range = 0.6               # Porcentagem de separação entre treino/teste
max_samples_per_period = 50     # limitação por 'segurança'
df_fc_p = MinimalFCParameters() # Ver documentação da biblioteca tsfresh - opção: EfficientFCParameters()
df_fc_p.pop('sum_values')       # Remove feature inapropriada
df_fc_p.pop('length')           # Remove feature inapropriada
max_nan_percent = 0.1           # Para seleção de variáveis
std_vars_min = 0.01             # Para seleção de variáveis
clfs = {}                       # Dicionário para lista de classificadores a serem experimentados
disable_progressbar = False      # Para menos saídas no notebook

# %%
def class_and_file_generator(data_path, real=False, simulated=False, drawn=False):
    """Gerador de lista contendo número da classe e caminho do arquivo de acordo com a fonte da instância."""    
    for class_path in data_path.iterdir():
        if class_path.is_dir():
            class_code = int(class_path.stem)
            for instance_path in class_path.iterdir():
                if (instance_path.suffix == '.csv'):
                    if (simulated and instance_path.stem.startswith('SIMULATED')) or \
                       (drawn and instance_path.stem.startswith('DRAWN')) or \
                       (real and (not instance_path.stem.startswith('SIMULATED')) and \
                       (not instance_path.stem.startswith('DRAWN'))):
                        yield class_code, instance_path

# %%
def load_instance(instance_path):
    """Função que carrega cada instância individualmente"""
    try:
        well, instance_id = instance_path.stem.split('_')
        df = pd.read_csv(instance_path, sep=',', header=0)
        assert (df.columns == columns).all(), \
            f'Colunas inválidas no arquivo {str(instance_path)}: {str(df.columns.tolist())}'
        return df
    except Exception as e:
        raise Exception(f'Erro ao ler arquivo {instance_path}: {e}')

# %%
def extract_samples(df, class_code):
    # Obtém os rótulos das observações e seu conjunto inequívoco
    ols = list(df['class'])
    set_ols = set()
    for ol in ols:
        if ol in set_ols or np.isnan(ol):
            continue
        set_ols.add(int(ol))       
    
    # Descarta os rótulos das observações e substitui todos os nan por 0
    # (requisito da biblioteca tsfresh)
    df_vars = df.drop('class', axis=1).fillna(0)  
    
    # Inicializa objetos que serão retornados
    df_samples_train = pd.DataFrame()
    df_samples_test = pd.DataFrame()
    y_train = []
    y_test = []
            
    # Descubre o número máximo de amostras em períodos normais, transitórios e em regime
    # Obtém índices (primeiro e último) sem sobreposição com outros períodos
    f_idx = ols.index(normal_class_code)
    l_idx = len(ols)-1-ols[::-1].index(normal_class_code)

    # Define o número inicial de amostras para o período normal
    max_samples_normal = l_idx-f_idx+1-sample_size
    if (max_samples_normal) > 0:      
        num_normal_samples = min(max_samples_per_period, max_samples_normal)
        num_train_samples = int(split_range*num_normal_samples)
        num_test_samples = num_normal_samples - num_train_samples    
    else:
        num_train_samples = 0
        num_test_samples = 0
    
    # Define o número máximo de amostras por período transitório
    transient_code = class_code + 100    
    if transient_code in set_ols:
        # Obtém índices (primeiro e último) com possível sobreposição
        # no início do período
        f_idx = ols.index(transient_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(transient_code)        
        max_transient_samples = l_idx-f_idx+1-sample_size
    else:
        max_transient_samples = 0            

    # Define o número máximo de amostras no período de regime
    if class_code in set_ols:
        # Obtém índices (primeiro e último) com possível sobreposição 
        # no início ou fim do período
        f_idx = ols.index(class_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(class_code)
        if l_idx+(sample_size-1) < len(ols)-1:
            l_idx = l_idx+(sample_size-1) 
        else:
            l_idx = len(ols)-1
        max_in_regime_samples = l_idx-f_idx+1-sample_size
    else:
        max_in_regime_samples = 0   
        
    # Descubre o número adequado de amostras em períodos normais, transitórios e em regime
    num_transient_samples = ceil(num_test_samples/2)
    num_in_regime_samples = num_test_samples - num_transient_samples
    if (max_transient_samples >= num_transient_samples) and \
       (max_in_regime_samples < num_in_regime_samples):
        num_in_regime_samples = max_in_regime_samples        
        num_transient_samples = min(num_test_samples-num_in_regime_samples, max_transient_samples)
    elif (max_transient_samples < num_transient_samples) and \
         (max_in_regime_samples >= num_in_regime_samples):
        num_transient_samples = max_transient_samples        
        num_in_regime_samples = min(num_test_samples-num_transient_samples, max_in_regime_samples)
    elif (max_transient_samples < num_transient_samples) and \
         (max_in_regime_samples < num_in_regime_samples):
        num_transient_samples = max_transient_samples
        num_in_regime_samples = max_in_regime_samples
        num_test_samples = num_transient_samples+num_in_regime_samples
    
    # Extrai amostras do período normal para treinamento e teste
    # Obtém índices (primeiro e último) sem sobreposição com outros períodos
    f_idx = ols.index(normal_class_code)
    l_idx = len(ols)-1-ols[::-1].index(normal_class_code)
    
    # Define a etapa correta e extrai amostras
    if (num_normal_samples) > 0:  
        if num_normal_samples == max_samples_normal:
            step_max = 1 
        else:
            step_max = (max_samples_normal-1) // (max_samples_per_period-1)
        step_wanted = sample_size
        step = min(step_wanted, step_max)
        
        # Extrai amostras para treinamento
        sample_id = 0
        for idx in range(num_train_samples):
            f_idx_c = l_idx-sample_size+1-(num_normal_samples-1-idx)*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_train = df_samples_train.append(df_sample)
            y_train.append(normal_class_code)
            sample_id += 1
    
        # Extrai amostras para teste
        sample_id = 0
        for idx in range(num_train_samples, num_train_samples+num_test_samples):
            f_idx_c = l_idx-sample_size+1-(num_normal_samples-1-idx)*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_test = df_samples_test.append(df_sample)
            y_test.append(normal_class_code)
            sample_id += 1

    # Extrai amostras do período transitório (se existir) para teste
    if (num_transient_samples) > 0:    
        # Define a etapa correta e extrai amostras
        if num_transient_samples == max_transient_samples:
            step_max = 1 
        else:
            step_max = (max_transient_samples-1) // (max_samples_per_period-1)
        step_wanted = np.inf
        step = min(step_wanted, step_max)
        
        # Obtém índices (primeiro e último) com possível sobreposição no início deste período
        f_idx = ols.index(transient_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(transient_code) 

        # Extrai amostras
        for idx in range(num_transient_samples):
            f_idx_c = f_idx+idx*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_test = df_samples_test.append(df_sample)
            y_test.append(transient_code)
            sample_id += 1
            
    # Extrai amostras do período em regime (se existir) para teste
    if (num_in_regime_samples) > 0:     
        # Define a etapa correta e extrai amostras
        if num_in_regime_samples == max_in_regime_samples:
            step_max = 1 
        else:
            step_max = (max_in_regime_samples-1) // (max_samples_per_period-1)
        step_wanted = sample_size
        step = min(step_wanted, step_max)
        
        # Obtém índices (primeiro e último) com possível sobreposição 
        # no início ou no final deste período
        f_idx = ols.index(class_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(class_code)
        if l_idx+(sample_size-1) < len(ols)-1:
            l_idx = l_idx+(sample_size-1) 
        else:
            l_idx = len(ols)-1

        # Extrai amostras
        for idx in range(num_in_regime_samples):
            f_idx_c = f_idx+idx*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_test = df_samples_test.append(df_sample)
            y_test.append(class_code)
            sample_id += 1
    '''       
    print(f'df_samples_train (antes de normalizar):')
    display(df_samples_train)
    print(f'y_train (antes de ajustar para +1 e -1): {y_train} \n')
    print(f'df_samples_test (antes de normalizar):')
    display(df_samples_test)
    print(f'y_test (antes de ajustar para +1 e -1): {y_test} \n')
    '''
    return df_samples_train, y_train, df_samples_test, y_test

# %%
def train_test_calc_scores(X_train, y_train, X_test, y_test, scores, clfs):
    X_train.reset_index(inplace=True, drop=True)
    X_test.reset_index(inplace=True, drop=True)    
    for clf_name, clf in clfs.items():
        #print(f'CLASSIFICADOR: {clf_name}')
        #print(f'y_train: {y_train}')
        #print(f'y_test: {y_test}')
        
        # Treino
        t0 = time()
        clf.fit(X_train, y_train)
        t_train = time() - t0

        # Teste
        t0 = time()
        y_pred = clf.predict(X_test)
        #print(f'y_pred: {y_pred}')
        t_test = time() - t0
        
        # Plota os labels reais e preditos pelo classificador
        '''
        fig = plt.figure(figsize=(12,1))
        ax = fig.add_subplot(111)
        plt.plot(-(y_pred), marker=11, color='orange', linestyle='') # Ordem invertida (mais natural)
        plt.plot(-(y_test), marker=10, color='green', linestyle='')  # Ordem invertida (mais natural)
        ax.grid(False)
        ax.set_yticks([-1, 1])
        ax.set_yticklabels(['Normal', 'Anormal'])
        ax.set_title(clf_name)            
        ax.set_xlabel('Amostra')
        ax.legend(['Classe Prevista', 'Classe Real'])
        plt.show()
        '''
        
        # Calcula as metricas de desempenho
        ret = precision_recall_fscore_support(y_test, y_pred, average='macro')
        p, r, f1, _ = ret
        scores = scores.append({'CLASSIFICADOR': clf_name, 
                                'PRECISAO': p,
                                'REVOGACAO': r,
                                'F1': f1,
                                'TREINAMENTO [s]': t_train, 
                                'TESTE [s] ': t_test}, ignore_index=True)  
    return scores

# %%
# Gets all real instances but maintains only those with any type of undesirable event
real_instances = pd.DataFrame(class_and_file_generator(data_path, 
                                                       real=True,
                                                       simulated=False, 
                                                       drawn=False),
                              columns=['class_code', 'instance_path'])
real_instances = real_instances.loc[real_instances.iloc[:,0].isin(abnormal_classes_codes)].reset_index(drop=True)

# %%
# For each real instance with any type of undesirable event
scores = pd.DataFrame()
ignored_instances = 0
used_instances = 0
for i, row in real_instances.iterrows():
    # Loads the current instance
    class_code, instance_path = row
    print(f'____________________________________________________________________________________')        
    print(f'Instância {i+1}: {instance_path}')
    df = load_instance(instance_path)
    
    # Ignores instances without sufficient normal periods
    normal_period_size = (df['class']==float(normal_class_code)).sum()
    if normal_period_size < min_normal_period_size:
        ignored_instances += 1
        print(f'\tignorado porque normal_period_size é insuficiente para treinamento ({normal_period_size})\n')
        continue
    used_instances += 1
        
    # Extracts samples from the current real instance
    df_samples_train, y_train, df_samples_test, y_test = extract_samples(df, class_code)

    # Changes types of the labels (tsfresh's requirement)
    y_train = np.array(y_train)
    y_test = np.array(y_test)
    
    # (Wander) incluidas as duas linhas abaixo para ajustar y_train também (?)
    y_train[y_train!=normal_class_code] = -1
    y_train[y_train==normal_class_code] = 1

    # We want binary classification: 1 for inliers (negative class = normal instance) and
    # -1 for outliers (positive class = instance with anomaly) (sklearn's requirement)
    y_test[y_test!=normal_class_code] = -1
    y_test[y_test==normal_class_code] = 1
    
    # Drops the bad vars
    good_vars = np.isnan(df_samples_train[vars]).mean(0) <= max_nan_percent
    std_vars = np.nanstd(df_samples_train[vars], 0)
    good_vars &= (std_vars > std_vars_min)    
    good_vars = list(good_vars.index[good_vars])
    bad_vars = list(set(vars)-set(good_vars))
    df_samples_train.drop(columns=bad_vars, inplace=True, errors='ignore')
    df_samples_test.drop(columns=bad_vars, inplace=True, errors='ignore')
    
    # Normalizes the samples (zero mean and unit variance)
    scaler = preprocessing.StandardScaler()
    df_samples_train[good_vars] = scaler.fit_transform(df_samples_train[good_vars]).astype('float32')
    df_samples_test[good_vars] = scaler.transform(df_samples_test[good_vars]).astype('float32')
    
    # Extracts features from samples
    X_train = extract_features(df_samples_train, 
                               column_id='id', 
                               column_sort='timestamp', 
                               default_fc_parameters=df_fc_p,
                               impute_function=impute,
                               n_jobs=0,
                               disable_progressbar=disable_progressbar)
    X_train = X_train.reset_index(drop=True)
    X_test = extract_features(df_samples_test, 
                              column_id='id', 
                              column_sort='timestamp',
                              default_fc_parameters=df_fc_p,
                              impute_function=impute,
                              n_jobs=0,
                              disable_progressbar=disable_progressbar)
    X_test = X_test.reset_index(drop=True)
    '''
    print(f'df_samples_train (normalizado e tratado):')
    display(df_samples_train)
    print(f'df_samples_test (normalizado):')
    display(df_samples_test)
    print(f'X_train:')
    display(X_train)
    print(f'y_train (ajustado para +1 e -1): {y_train} \n')
    print(f'X_test:')
    display(X_test)
    print(f'y_test (ajustado para +1 e -1): {y_test} \n')
    '''
    # LISTA DE CLASSIFICADORES A SEREM EXPERIMENTADOS
        
    # DUMMY - Classificador ingênuo
    clfs['Dummy'] = DummyClassifier(strategy='constant', constant=1)
    
    # ISOLATION FOREST - busca de melhores hiperparâmetros (384 combinações)
    isolation_forest_params = {
        'n_estimators': [50, 100, 150, 200],
        'max_samples': ['auto', 0.50, 0.75, 1.0],
        'contamination': ['auto', 0, 0.05, 0.10],
        'bootstrap': [True, False],
        'max_features': [0.50, 0.75, 1.0],
        'random_state': [random_state]
    }
    for params in ParameterGrid(isolation_forest_params):
        isolation_forest_clf = IsolationForest().set_params(**params)
        clfs[f'Floresta de Isolamento: {params}'] = isolation_forest_clf

    # ONE CLASS SVM - busca de melhores hiperparâmetros (240 combinações)
    ocsvm_params = {
        'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
        'gamma': ['auto', 'scale', 1e-4, 1e-3, 1e-2, 0.1, 0.50, 1.0, 5.0, 10.0], # kernel coefficient para 'rbf', 'poly' and 'sigmoid'.
        'nu': [1e-4, 1e-3, 1e-2, 0.10, 0.50, 1.0]
    }    
    for params in ParameterGrid(ocsvm_params):
        ocsvm_clf = OneClassSVM().set_params(**params)
        clfs[f'One-Class SVM: {params}'] = ocsvm_clf
    
    # LOCAL OUTLIER FACTOR (LOF) - busca de melhores hiperparâmetros (1056 combinações)
    lof_params = {
        'n_neighbors': [5, 10, 15, 20],
        'algorithm': ['auto'],
        'leaf_size': [15, 30, 45], # Leaf size passed to BallTree or KDTree algorithm. 
        'metric': ['cityblock', 'cosine', 'euclidean', 'l1', 'l2', 'manhattan', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'dice', 'hamming', 'jaccard', 'kulsinski', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule'],
        'contamination': ['auto', 0.01, 0.05, 0.10],
        'novelty': [True]
    }    
    for params in ParameterGrid(lof_params):
        lof_clf = LocalOutlierFactor().set_params(**params)
        clfs[f'Local Outlier Factor (LOF): {params}'] = lof_clf
    
    # ELLIPTIC ENVELOPE(LOF) - busca de melhores hiperparâmetros (36 combinações)
    ellipticenvelope_params = {
        'contamination': [1e-4, 1e-3, 0.01, 0.05, 0.10, 0.50],
        'assume_centered': [True, False],
        'support_fraction': [0.80, 0.90, 0.99], # proportion of points to be included in the support of the raw MCD estimate. 
        'random_state': [random_state]
    }    
    for params in ParameterGrid(ellipticenvelope_params):
        ellipticenvelope_clf = EllipticEnvelope().set_params(**params)
        clfs[f'Envelope Elíptico: {params}'] = ellipticenvelope_clf
    
    # Treina, testa e calcula os scores para cada classificador na instância    
    scores = train_test_calc_scores(X_train, y_train, X_test, y_test, scores, clfs)
# Out:
# ____________________________________________________________________________________
# Instância 1: data\1\WELL-00001_20140124213136.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (959)
#
# ____________________________________________________________________________________
# Instância 2: data\1\WELL-00002_20140126200050.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (1138)
#
# ____________________________________________________________________________________
# Instância 3: data\1\WELL-00006_20170801063614.csv
# Feature Extraction: 100%|██████████| 120/120 [00:00<00:00, 3149.55it/s]
# Feature Extraction: 100%|██████████| 160/160 [00:00<00:00, 3312.92it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4273bec2e3e9> in <module>
#     130
#     131     # Treina, testa e calcula os scores para cada classificador na instância
# --> 132     scores = train_test_calc_scores(X_train, y_train, X_test, y_test, scores, clfs)
#
# <ipython-input-9-816372005857> in train_test_calc_scores(X_train, y_train, X_test, y_test, scores, clfs)
#       9         # Treino
#      10         t0 = time()
# ---> 11         clf.fit(X_train, y_train)
#      12         t_train = time() - t0
#      13
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neighbors\_lof.py in fit(self, X, y)
#     259                                  "got: %f" % self.contamination)
#     260
# --> 261         super().fit(X)
#     262
#     263         n_samples = self.n_samples_fit_
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1171             or [n_samples, n_samples] if metric='precomputed'.
#    1172         """
# -> 1173         return self._fit(X)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X)
#     450
#     451         if self._fit_method == 'ball_tree':
# --> 452             self._tree = BallTree(X, self.leaf_size,
#     453                                   metric=self.effective_metric_,
#     454                                   **self.effective_metric_params_)
#
# sklearn\neighbors\_binary_tree.pxi in sklearn.neighbors._ball_tree.BinaryTree.__init__()
#
# sklearn\neighbors\_dist_metrics.pyx in sklearn.neighbors._dist_metrics.DistanceMetric.get_metric()
#
# sklearn\neighbors\_dist_metrics.pyx in sklearn.neighbors._dist_metrics.SEuclideanDistance.__init__()
#
# TypeError: __init__() takes exactly 1 positional argument (0 given)

# %% [markdown]
# ## 3. Resultados

# %% [markdown]
# Os resultados obtidos com os métodos implementados são apresentados abaixo.

# %%
print(f'Número de instâncias utilizadas: {used_instances}')
print(f'Número de instâncias ignoradas: {ignored_instances}')
# Out:
# Número de instâncias utilizadas: 36
# Número de instâncias ignoradas: 16

# %%
print(f'Características utilizadas: {list(df_fc_p.keys())}')
# Out:
# Características utilizadas: ['median', 'mean', 'standard_deviation', 'variance', 'maximum', 'minimum']

# %% [markdown]
# Os comandos a seguir permitem salvar e recuperar os resultados de/para um arquivo CSV de forma conveniente.

# %%
scores.to_csv(r'./results/anomaly_detection_scores_por_rodada_Macro.csv')

# %% [markdown]
# ### 3.1. Métricas em formato tabular

# %% [markdown]
# As tabelas a seguir apresentam as médias e o desvio padrão das métricas, respectivamente. Ambos são ordenados pela medida-F1.

# %%
# Médias
mean_score_table = scores.groupby('CLASSIFICADOR').mean().sort_values(by=['F1'], ascending=False)
mean_score_table.to_csv(r'./results/anomaly_detection_scores_medias_Macro.csv')
mean_score_table
# Out:
#                                                           F1  PRECISAO  \
# CLASSIFICADOR
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.870872  0.900102
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.870872  0.900102
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.870872  0.900102
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.870872  0.900102
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.870872  0.900102
# ...                                                      ...       ...
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'sig...  0.246525  0.200702
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...  0.246525  0.200702
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...  0.246525  0.200702
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...  0.246525  0.200702
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...  0.246525  0.200702
#
#                                                     REVOGACAO  TESTE [s]   \
# CLASSIFICADOR
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.881944    0.001609
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.881944    0.001468
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.881944    0.001760
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.881944    0.001633
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.881944    0.001363
# ...                                                       ...         ...
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'sig...   0.342593    0.001136
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...   0.342593    0.001136
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...   0.342593    0.001384
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...   0.342593    0.001136
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...   0.342593    0.001110
#
#                                                     TREINAMENTO [s]
# CLASSIFICADOR
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001783
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001661
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001633
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001690
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001909
# ...                                                             ...
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'sig...         0.001460
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...         0.001521
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...         0.001440
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...         0.001372
# One-Class SVM: {'gamma': 0.0001, 'kernel': 'pol...         0.001716
#
# [1717 rows x 5 columns]

# %%
# Desvios Padrão
std_score_table = scores.groupby('CLASSIFICADOR').std().sort_values(by=['F1'], ascending=True)
std_score_table.to_csv(r'./results/anomaly_detection_scores_desvios_padrao_Macro.csv')
std_score_table
# Out:
#                                                           F1  PRECISAO  \
# CLASSIFICADOR
# Dummy                                               0.000000  0.000000
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.000000  0.000000
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.000000  0.000000
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.000000  0.000000
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.000000  0.000000
# ...                                                      ...       ...
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.295978  0.344053
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.295978  0.344053
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.305047  0.351625
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.305047  0.351625
# Local Outlier Factor (LOF): {'algorithm': 'auto...  0.305047  0.351625
#
#                                                     REVOGACAO  TESTE [s]   \
# CLASSIFICADOR
# Dummy                                                0.000000    0.000166
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.000000    0.000564
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.000000    0.000732
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.000000    0.000835
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.000000    0.000657
# ...                                                       ...         ...
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.214999    0.000716
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.214999    0.000553
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.223742    0.000675
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.223742    0.000716
# Local Outlier Factor (LOF): {'algorithm': 'auto...   0.223742    0.000665
#
#                                                     TREINAMENTO [s]
# CLASSIFICADOR
# Dummy                                                      0.000499
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000652
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000846
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000548
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000524
# ...                                                             ...
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001248
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000654
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.001158
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000791
# Local Outlier Factor (LOF): {'algorithm': 'auto...         0.000495
#
# [1717 rows x 5 columns]

# %% [markdown]
# ### 3.2. Testes estatísticos

# %% [markdown]
# Utilizado teste de Friedman e teste de Holm.

# %%
# Teste Estatístico (Friedman)

clfs_names = list(clfs.keys())
f1s = [scores.loc[scores['CLASSIFICADOR']==cn, 'F1'].values for cn in clfs_names]
f_value_stat, p_value, ranks, pivots = stac.friedman_test(*(f1s))
print(f'p_value: {p_value}')
# Out:
# p_value: 1.1102230246251565e-16

# %%
# Teste Estatístico (Holm)

comp, z_values_stat, p_values, adj_p_values = stac.holm_test(len(pivots), pivots, clfs_names, clfs_names.index('Dummy'))
for i in range(len(comp)):
    print(f'{comp[i]}: \n\tp_values: {p_values[i]}\n\tadj_p_values: {adj_p_values[i]}')
# Out:
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'cityblock', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'cityblock', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'cityblock', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'euclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'euclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'euclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l1', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l1', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l1', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l2', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l2', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l2', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'manhattan', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'manhattan', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'manhattan', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'chebyshev', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'chebyshev', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'chebyshev', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'minkowski', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'minkowski', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'minkowski', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'cityblock', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'cityblock', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'cityblock', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'euclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'euclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'euclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l1', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l1', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l1', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l2', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l2', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l2', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'chebyshev', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'chebyshev', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'chebyshev', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'cityblock', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'cityblock', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'cityblock', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'euclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'euclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'euclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l1', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l1', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l1', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l2', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l2', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l2', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'manhattan', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'manhattan', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'manhattan', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'chebyshev', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'chebyshev', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'chebyshev', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'minkowski', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'minkowski', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'minkowski', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 0.0
# 	adj_p_values: 0.0
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'sqeuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'sqeuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'sqeuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'sqeuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'sqeuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'sqeuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'sqeuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'sqeuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'sqeuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 4.440892098500626e-16
# 	adj_p_values: 7.340794638821535e-13
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.9984014443252818e-15
# 	adj_p_values: 3.2853719744707632e-12
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.9984014443252818e-15
# 	adj_p_values: 3.2853719744707632e-12
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.9984014443252818e-15
# 	adj_p_values: 3.2853719744707632e-12
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'chebyshev', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 5.0182080713057076e-14
# 	adj_p_values: 8.234879445012666e-11
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'chebyshev', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 5.0182080713057076e-14
# 	adj_p_values: 8.234879445012666e-11
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'chebyshev', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 5.0182080713057076e-14
# 	adj_p_values: 8.234879445012666e-11
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'cityblock', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l1', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'manhattan', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'cityblock', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l1', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'cityblock', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l1', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'manhattan', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 7.549516567451064e-14
# 	adj_p_values: 1.2366108137484844e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'euclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'l2', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'minkowski', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'euclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'l2', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'euclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'l2', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'minkowski', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 8.326672684688674e-14
# 	adj_p_values: 1.356414980335785e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 3.0686564400639327e-13
# 	adj_p_values: 4.971223432903571e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 3.0686564400639327e-13
# 	adj_p_values: 4.971223432903571e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 3.0686564400639327e-13
# 	adj_p_values: 4.971223432903571e-10
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.951327988081175e-12
# 	adj_p_values: 3.15529735672726e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.951327988081175e-12
# 	adj_p_values: 3.15529735672726e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.951327988081175e-12
# 	adj_p_values: 3.15529735672726e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.325473147379853e-12
# 	adj_p_values: 3.7533136598710826e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.325473147379853e-12
# 	adj_p_values: 3.7533136598710826e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.325473147379853e-12
# 	adj_p_values: 3.7533136598710826e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 2.743805183058612e-12
# 	adj_p_values: 4.420270149907424e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.901456852555384e-12
# 	adj_p_values: 4.648133877793725e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.901456852555384e-12
# 	adj_p_values: 4.648133877793725e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.901456852555384e-12
# 	adj_p_values: 4.648133877793725e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 5.9967586452103205e-12
# 	adj_p_values: 9.588817073691303e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 5.9967586452103205e-12
# 	adj_p_values: 9.588817073691303e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 5.9967586452103205e-12
# 	adj_p_values: 9.588817073691303e-09
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 2.8356428316556048e-11
# 	adj_p_values: 4.525685959322345e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'canberra', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 3.611266841119232e-11
# 	adj_p_values: 5.731080476856221e-08
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 0.75, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 1.899327362053782e-10
# 	adj_p_values: 2.997138577320868e-07
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 4.450602109073998e-10
# 	adj_p_values: 7.018599526009695e-07
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 4.450602109073998e-10
# 	adj_p_values: 7.018599526009695e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 5.862512697518696e-10
# 	adj_p_values: 9.233457498591946e-07
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'seuclidean', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 7.286629077896123e-10
# 	adj_p_values: 1.1410861135985328e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'chebyshev', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.2081675659914026e-09
# 	adj_p_values: 1.8702433921546913e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'chebyshev', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.2081675659914026e-09
# 	adj_p_values: 1.8702433921546913e-06
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'chebyshev', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.2081675659914026e-09
# 	adj_p_values: 1.8702433921546913e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 1.2677559002582939e-09
# 	adj_p_values: 1.958682865899064e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 0.75, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 1.3204064508443025e-09
# 	adj_p_values: 2.038707560103603e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 3.2541738193003766e-09
# 	adj_p_values: 5.021190203180481e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 3.2541738193003766e-09
# 	adj_p_values: 5.021190203180481e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 0.75, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 4.171869072422396e-09
# 	adj_p_values: 6.4288502406029124e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 5.52933898667618e-09
# 	adj_p_values: 8.515182039481317e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 5.52933898667618e-09
# 	adj_p_values: 8.515182039481317e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 5.70935809740547e-09
# 	adj_p_values: 8.780992753809613e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 5.70935809740547e-09
# 	adj_p_values: 8.780992753809613e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 5.937135005851246e-09
# 	adj_p_values: 9.119439368987514e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 5.937135005851246e-09
# 	adj_p_values: 9.119439368987514e-06
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 6.552902886980405e-09
# 	adj_p_values: 1.0052153028627941e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 6.552902886980405e-09
# 	adj_p_values: 1.0052153028627941e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 6.60420207410084e-09
# 	adj_p_values: 1.0117637577522487e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 6.60420207410084e-09
# 	adj_p_values: 1.0117637577522487e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.1, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 7.2870629530541464e-09
# 	adj_p_values: 1.1149206318172844e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 0.75, 'max_samples': 0.75, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 7.931415524353724e-09
# 	adj_p_values: 1.2127134336736844e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 0.75, 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 8.192828193642754e-09
# 	adj_p_values: 1.2518641479886128e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 0.75, 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 8.41507952209497e-09
# 	adj_p_values: 1.284982643023902e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.1, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 1.1234063457266075e-08
# 	adj_p_values: 1.714318083578803e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 1.0, 'max_samples': 0.75, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 1.1821265522016233e-08
# 	adj_p_values: 1.8027429921074756e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 1.1912294706206694e-08
# 	adj_p_values: 1.8154337132259002e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 1.1912294706206694e-08
# 	adj_p_values: 1.8154337132259002e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.5575490674990533e-08
# 	adj_p_values: 2.370589680733559e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.5575490674990533e-08
# 	adj_p_values: 2.370589680733559e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.607901412015167e-08
# 	adj_p_values: 2.4440101462630537e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.607901412015167e-08
# 	adj_p_values: 2.4440101462630537e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.1, 'max_features': 1.0, 'max_samples': 0.5, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 1.741999011706241e-08
# 	adj_p_values: 2.644354499770074e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 1.7870114277229732e-08
# 	adj_p_values: 2.7108963358557503e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 1.7870114277229732e-08
# 	adj_p_values: 2.7108963358557503e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.1, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.7981300004521472e-08
# 	adj_p_values: 2.724166950685003e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.1, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.7981300004521472e-08
# 	adj_p_values: 2.724166950685003e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 0.75, 'n_estimators': 50, 'random_state': 1}:
# 	p_values: 1.813059324895505e-08
# 	adj_p_values: 2.7431587585668993e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 0.75, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 2.209715610490548e-08
# 	adj_p_values: 3.3410900030617086e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 1.0, 'max_samples': 0.75, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 2.351706762659944e-08
# 	adj_p_values: 3.5534289183791756e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 0.5, 'max_samples': 'auto', 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 2.4152357003259795e-08
# 	adj_p_values: 3.647005907492229e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0, 'max_features': 0.5, 'max_samples': 1.0, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 2.4152357003259795e-08
# 	adj_p_values: 3.647005907492229e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.1, 'max_features': 1.0, 'max_samples': 0.75, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.5490668909000647e-08
# 	adj_p_values: 3.8439928714772975e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.5647625578884004e-08
# 	adj_p_values: 3.865097174737819e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': False, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.5647625578884004e-08
# 	adj_p_values: 3.865097174737819e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 0.5, 'max_samples': 0.75, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.575278412741966e-08
# 	adj_p_values: 3.875794011176659e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.646461005895162e-08
# 	adj_p_values: 3.980277352866324e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0.05, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.646461005895162e-08
# 	adj_p_values: 3.980277352866324e-05
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 0, 'max_features': 0.75, 'max_samples': 0.75, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 2.734402682058601e-08
# 	adj_p_values: 4.1070728284520186e-05
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'sqeuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.7493327170446946e-08
# 	adj_p_values: 4.1267484082840866e-05
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'sqeuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.7493327170446946e-08
# 	adj_p_values: 4.1267484082840866e-05
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'sqeuclidean', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 2.7493327170446946e-08
# 	adj_p_values: 4.1267484082840866e-05
# ...
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 'auto', 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 100, 'random_state': 1}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 'auto', 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 150, 'random_state': 1}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Floresta de Isolamento: {'bootstrap': True, 'contamination': 'auto', 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 200, 'random_state': 1}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'auto', 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'auto', 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'auto', 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'auto', 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'auto', 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'scale', 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'scale', 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'scale', 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'scale', 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 'scale', 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 0.01}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.0001, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.001, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.001, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.001, 'kernel': 'rbf', 'nu': 0.001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.001, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.001, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.001, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.01, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.01, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.01, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.01, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.01, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.1, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.1, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.1, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.1, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.1, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.5, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.5, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.5, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.5, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 0.5, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 1.0, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 1.0, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 1.0, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 1.0, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 1.0, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 5.0, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 5.0, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 5.0, 'kernel': 'rbf', 'nu': 0.001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 5.0, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 5.0, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 5.0, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 10.0, 'kernel': 'linear', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 10.0, 'kernel': 'rbf', 'nu': 0.0001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 10.0, 'kernel': 'rbf', 'nu': 0.001}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 10.0, 'kernel': 'rbf', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 10.0, 'kernel': 'poly', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs One-Class SVM: {'gamma': 10.0, 'kernel': 'sigmoid', 'nu': 1.0}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'hamming', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'hamming', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'hamming', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'hamming', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'hamming', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'hamming', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'hamming', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'hamming', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'hamming', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'hamming', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'hamming', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'hamming', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 'auto', 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 5, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.01, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.05, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 15, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 30, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 10, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 15, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1
# Dummy vs Local Outlier Factor (LOF): {'algorithm': 'auto', 'contamination': 0.1, 'leaf_size': 45, 'metric': 'yule', 'n_neighbors': 20, 'novelty': True}:
# 	p_values: 1.0
# 	adj_p_values: 1

# %%
# Calcular tempo total do notebook Jupyter
print(f'Tempo total de execução (hh:mm:ss.ms): {datetime.now() - start_time}')
# Out:
# Tempo total de execução (hh:mm:ss.ms): 1:07:37.347796
